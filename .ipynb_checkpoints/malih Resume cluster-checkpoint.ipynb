# %%
# we get a dataframe with the following values returned
# college_name, company_names, degree, designation, skills, location, total_experience, best_role

# %%
conda install -c conda-forge python-annoy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.14.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/macbook/opt/anaconda3
#
#   added / updated specs:
#     - python-annoy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.12.0               |   py38h50d1736_0        1020 KB  conda-forge
#     python-annoy-1.16.3        |   py38hc84c608_3          59 KB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   python-annoy       conda-forge/osx-64::python-annoy-1.16.3-py38hc84c608_3
#   python_abi         conda-forge/osx-64::python_abi-3.8-2_cp38
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-4.10.1-py38hecd8cb5_1 --> conda-forge::conda-4.12.0-py38h50d1736_0
#
#
#
# Downloading and Extracting Packages
# conda-4.12.0         | 1020 KB   | ##################################### | 100%
# python_abi-3.8       | 4 KB      | ##################################### | 100%
# python-annoy-1.16.3  | 59 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
from gensim import corpora
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from pymystem3 import Mystem
from sklearn.feature_extraction.text import TfidfVectorizer

import umap.umap_ as umap
import scipy.cluster.hierarchy as shc

from annoy import AnnoyIndex

# %%
df = pd.read_csv("UpdatedResumeDataSet.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-def32d9b063f> in <module>
# ----> 1 df = pd.read_csv("UpdatedResumeDataSet.csv")
#
# NameError: name 'pd' is not defined

# %%
#df2 = df.iloc[:,0:4][:,8:11]
df2 = df.iloc[:,[0,1,2,3,8,9,10]]

# %%
df2
# Out:
#              college_name     company_names                         degree  \
# 0      Harvard University              Meta   B.E. IN COMPUTER ENGINEERING
# 1   College of Charleston      Boeing, Ford          B.S. COMPUTER SCIENCE
# 2   University of Chicago  Apple, Microsoft                  MS Statistics
# 3    Dominican University    Reesby, Indeed                M.S. Psychology
# 4  University of Illinois     Meta, MongoDB  Bachelors in Computer Science
# 5  University of Illinois           MongoDB  Bachelors in Computer Science
# 6  University of Delaware         Glassdoor                           None
#
#                                          designation  \
# 0  Manager, TECHNICIAL CONTENT WRITER, DATA ENGINEER
# 1                                front-end developer
# 2                                     data scientist
# 3                            Human Relations Manager
# 4                                                NaN
# 5                                                NaN
# 6                            Human Relations Manager
#
#                                               skills               location  \
# 0  Operating systems, Linux, Github, Testing, Con...           Delhi, India
# 1               html, css, react, bootstrap, flexbox             Charleston
# 2  cleaning data, statatistical analysis, data an...      Sydney, Australia
# 3  Recruiting, Interviewing, management, microsof...          Melbourne, AU
# 4         github, node.js, python, django, html, css  San Diego, California
# 5         github, node.js, python, django, html, css  San Diego, California
# 6   Employee relations, management, administrative,              Sydney, AU
#
#    total_experience
# 0              1.83
# 1              1.00
# 2              3.00
# 3              2.00
# 4              1.00
# 5              1.00
# 6              1.00

# %%
df2.insert(6, "all_contents", "", True)

# %%
df2
# Out:
#              college_name     company_names                         degree  \
# 0      Harvard University              Meta   B.E. IN COMPUTER ENGINEERING
# 1   College of Charleston      Boeing, Ford          B.S. COMPUTER SCIENCE
# 2   University of Chicago  Apple, Microsoft                  MS Statistics
# 3    Dominican University    Reesby, Indeed                M.S. Psychology
# 4  University of Illinois     Meta, MongoDB  Bachelors in Computer Science
# 5  University of Illinois           MongoDB  Bachelors in Computer Science
# 6  University of Delaware         Glassdoor                           None
#
#                                          designation  \
# 0  Manager, TECHNICIAL CONTENT WRITER, DATA ENGINEER
# 1                                front-end developer
# 2                                     data scientist
# 3                            Human Relations Manager
# 4                                                NaN
# 5                                                NaN
# 6                            Human Relations Manager
#
#                                               skills               location  \
# 0  Operating systems, Linux, Github, Testing, Con...           Delhi, India
# 1               html, css, react, bootstrap, flexbox             Charleston
# 2  cleaning data, statatistical analysis, data an...      Sydney, Australia
# 3  Recruiting, Interviewing, management, microsof...          Melbourne, AU
# 4         github, node.js, python, django, html, css  San Diego, California
# 5         github, node.js, python, django, html, css  San Diego, California
# 6   Employee relations, management, administrative,              Sydney, AU
#
#   all_contents  total_experience
# 0                           1.83
# 1                           1.00
# 2                           3.00
# 3                           2.00
# 4                           1.00
# 5                           1.00
# 6                           1.00

# %%
all_contents_column = []
for index in df2.index:
    row = df2.iloc[index] #index=1 => second row
    rows_contents = []
    for i in range(6):
        rows_contents.append(str(row[i]))
    all_contents_column.append(" ".join(rows_contents))
    print(row['all_contents'])

df2['all_contents'] = all_contents_column
# Out:
# C:\Users\tiffa\AppData\Local\Temp\ipykernel_13320\3432770260.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['all_contents'] = all_contents_column

# %%
df2
# Out:
#              college_name     company_names                         degree  \
# 0      Harvard University              Meta   B.E. IN COMPUTER ENGINEERING
# 1   College of Charleston      Boeing, Ford          B.S. COMPUTER SCIENCE
# 2   University of Chicago  Apple, Microsoft                  MS Statistics
# 3    Dominican University    Reesby, Indeed                M.S. Psychology
# 4  University of Illinois     Meta, MongoDB  Bachelors in Computer Science
# 5  University of Illinois           MongoDB  Bachelors in Computer Science
# 6  University of Delaware         Glassdoor                           None
#
#                                          designation  \
# 0  Manager, TECHNICIAL CONTENT WRITER, DATA ENGINEER
# 1                                front-end developer
# 2                                     data scientist
# 3                            Human Relations Manager
# 4                                                NaN
# 5                                                NaN
# 6                            Human Relations Manager
#
#                                               skills               location  \
# 0  Operating systems, Linux, Github, Testing, Con...           Delhi, India
# 1               html, css, react, bootstrap, flexbox             Charleston
# 2  cleaning data, statatistical analysis, data an...      Sydney, Australia
# 3  Recruiting, Interviewing, management, microsof...          Melbourne, AU
# 4         github, node.js, python, django, html, css  San Diego, California
# 5         github, node.js, python, django, html, css  San Diego, California
# 6   Employee relations, management, administrative,              Sydney, AU
#
#                                         all_contents  total_experience
# 0  Harvard University Meta B.E. IN COMPUTER ENGIN...              1.83
# 1  College of Charleston Boeing, Ford B.S. COMPUT...              1.00
# 2  University of Chicago Apple, Microsoft MS Stat...              3.00
# 3  Dominican University Reesby, Indeed M.S. Psych...              2.00
# 4  University of Illinois Meta, MongoDB Bachelors...              1.00
# 5  University of Illinois MongoDB Bachelors in Co...              1.00
# 6  University of Delaware Glassdoor None Human Re...              1.00

# %%
df3 = df2['all_contents']
df3
# Out:
# 0    Harvard University Meta B.E. IN COMPUTER ENGIN...
# 1    College of Charleston Boeing, Ford B.S. COMPUT...
# 2    University of Chicago Apple, Microsoft MS Stat...
# 3    Dominican University Reesby, Indeed M.S. Psych...
# 4    University of Illinois Meta, MongoDB Bachelors...
# 5    University of Illinois MongoDB Bachelors in Co...
# 6    University of Delaware Glassdoor None Human Re...
# Name: all_contents, dtype: object

# %%
def remove_numbers(documents):
    return [''.join([i for i in doc if not i.isdigit()]) for doc in documents]

def remove_strange_char(documents):
    return [re.sub(r'[^a-zA-Z0-9\#_+-]',r' ', doc) for doc in documents]

def make_tokenize(documents):
    return [doc.lower().split() for doc in documents]

def remove_stopwords(documents):
    stopset = stopwords.words('english')
    return [[word for word in doc if word not in stopset] for doc in documents]

def lemmetization(documents):
    lemm=Mystem()
    return [[''.join(lemm.lemmatize(word)).replace('\n', '') for word in doc] for doc in documents]

# %%
docs = df3.fillna('').tolist()
docs
# Out:
# ['Harvard University Meta B.E. IN COMPUTER ENGINEERING Manager, TECHNICIAL CONTENT WRITER, DATA ENGINEER Operating systems, Linux, Github, Testing, Content, Automation, Python, Css, Website, Django, Opencv, Programming, C Delhi, India',
#  'College of Charleston Boeing, Ford B.S. COMPUTER SCIENCE front-end developer html, css, react, bootstrap, flexbox Charleston',
#  'University of Chicago Apple, Microsoft MS Statistics data scientist cleaning data, statatistical analysis, data analysis, calculus, python Sydney, Australia',
#  'Dominican University Reesby, Indeed M.S. Psychology Human Relations Manager Recruiting, Interviewing, management, microsoft office suite Melbourne, AU',
#  'University of Illinois Meta, MongoDB Bachelors in Computer Science nan github, node.js, python, django, html, css San Diego, California',
#  'University of Illinois MongoDB Bachelors in Computer Science nan github, node.js, python, django, html, css San Diego, California',
#  'University of Delaware Glassdoor None Human Relations Manager Employee relations, management, administrative,  Sydney, AU']

# %%
docs = remove_strange_char(docs)
docs
# Out:
# ['Harvard University Meta B E  IN COMPUTER ENGINEERING Manager  TECHNICIAL CONTENT WRITER  DATA ENGINEER Operating systems  Linux  Github  Testing  Content  Automation  Python  Css  Website  Django  Opencv  Programming  C Delhi  India',
#  'College of Charleston Boeing  Ford B S  COMPUTER SCIENCE front-end developer html  css  react  bootstrap  flexbox Charleston',
#  'University of Chicago Apple  Microsoft MS Statistics data scientist cleaning data  statatistical analysis  data analysis  calculus  python Sydney  Australia',
#  'Dominican University Reesby  Indeed M S  Psychology Human Relations Manager Recruiting  Interviewing  management  microsoft office suite Melbourne  AU',
#  'University of Illinois Meta  MongoDB Bachelors in Computer Science nan github  node js  python  django  html  css San Diego  California',
#  'University of Illinois MongoDB Bachelors in Computer Science nan github  node js  python  django  html  css San Diego  California',
#  'University of Delaware Glassdoor None Human Relations Manager Employee relations  management  administrative   Sydney  AU']

# %%
docs = remove_numbers(docs)
docs
# Out:
# ['Harvard University Meta B E  IN COMPUTER ENGINEERING Manager  TECHNICIAL CONTENT WRITER  DATA ENGINEER Operating systems  Linux  Github  Testing  Content  Automation  Python  Css  Website  Django  Opencv  Programming  C Delhi  India',
#  'College of Charleston Boeing  Ford B S  COMPUTER SCIENCE front-end developer html  css  react  bootstrap  flexbox Charleston',
#  'University of Chicago Apple  Microsoft MS Statistics data scientist cleaning data  statatistical analysis  data analysis  calculus  python Sydney  Australia',
#  'Dominican University Reesby  Indeed M S  Psychology Human Relations Manager Recruiting  Interviewing  management  microsoft office suite Melbourne  AU',
#  'University of Illinois Meta  MongoDB Bachelors in Computer Science nan github  node js  python  django  html  css San Diego  California',
#  'University of Illinois MongoDB Bachelors in Computer Science nan github  node js  python  django  html  css San Diego  California',
#  'University of Delaware Glassdoor None Human Relations Manager Employee relations  management  administrative   Sydney  AU']

# %%
docs = make_tokenize(docs)
docs
# Out:
# [['harvard',
#   'university',
#   'meta',
#   'b',
#   'e',
#   'in',
#   'computer',
#   'engineering',
#   'manager',
#   'technicial',
#   'content',
#   'writer',
#   'data',
#   'engineer',
#   'operating',
#   'systems',
#   'linux',
#   'github',
#   'testing',
#   'content',
#   'automation',
#   'python',
#   'css',
#   'website',
#   'django',
#   'opencv',
#   'programming',
#   'c',
#   'delhi',
#   'india'],
#  ['college',
#   'of',
#   'charleston',
#   'boeing',
#   'ford',
#   'b',
#   's',
#   'computer',
#   'science',
#   'front-end',
#   'developer',
#   'html',
#   'css',
#   'react',
#   'bootstrap',
#   'flexbox',
#   'charleston'],
#  ['university',
#   'of',
#   'chicago',
#   'apple',
#   'microsoft',
#   'ms',
#   'statistics',
#   'data',
#   'scientist',
#   'cleaning',
#   'data',
#   'statatistical',
#   'analysis',
#   'data',
#   'analysis',
#   'calculus',
#   'python',
#   'sydney',
#   'australia'],
#  ['dominican',
#   'university',
#   'reesby',
#   'indeed',
#   'm',
#   's',
#   'psychology',
#   'human',
#   'relations',
#   'manager',
#   'recruiting',
#   'interviewing',
#   'management',
#   'microsoft',
#   'office',
#   'suite',
#   'melbourne',
#   'au'],
#  ['university',
#   'of',
#   'illinois',
#   'meta',
#   'mongodb',
#   'bachelors',
#   'in',
#   'computer',
#   'science',
#   'nan',
#   'github',
#   'node',
#   'js',
#   'python',
#   'django',
#   'html',
#   'css',
#   'san',
#   'diego',
#   'california'],
#  ['university',
#   'of',
#   'illinois',
#   'mongodb',
#   'bachelors',
#   'in',
#   'computer',
#   'science',
#   'nan',
#   'github',
#   'node',
#   'js',
#   'python',
#   'django',
#   'html',
#   'css',
#   'san',
#   'diego',
#   'california'],
#  ['university',
#   'of',
#   'delaware',
#   'glassdoor',
#   'none',
#   'human',
#   'relations',
#   'manager',
#   'employee',
#   'relations',
#   'management',
#   'administrative',
#   'sydney',
#   'au']]

# %%
# docs = lemmetization(docs)
# docs

# %%
corpus = [' '.join(doc) for doc in docs]

def dummy_fun(doc):
    return doc

vectorizer = TfidfVectorizer(ngram_range=(1,3),
                            max_df=0.5,
                            min_df=0.05,
                            tokenizer=dummy_fun,
                            token_pattern=None,
                            preprocessor=dummy_fun)

X = vectorizer.fit_transform(docs)

# %%
X
# Out:
# <7x289 sparse matrix of type '<class 'numpy.float64'>'
# 	with 357 stored elements in Compressed Sparse Row format>

# %%
def get_umap(data, c=None, n_neighbors=2, min_dist=0.2, n_components=2, metric='cosine', title=''):
    fit = umap.UMAP(
    n_neighbors=n_neighbors,
    min_dist=min_dist,
    n_components=n_components,
    metric=metric,
    random_state=1
    )
    u = fit.fit_transform(data)
    return u

data = X.toarray()
umap = get_umap(data)

new_df = pd.DataFrame()

new_df['umap_0'] = umap[:,0]
new_df['umap_1'] = umap[:,1]

# %%
new_df
# Out:
#       umap_0     umap_1
# 0 -10.575815  21.208315
# 1  -8.570870  22.338779
# 2 -10.456003  20.521410
# 3 -14.056956  -8.242469
# 4 -10.015450  21.819975
# 5  -9.284994  22.010324
# 6 -14.502696  -8.688220

# %%
plt.figure(figsize=(10,7))
sns.lmplot(x="umap_0",
          y="umap_1",
          data=new_df,
          fit_reg=False,
          legend=True,
          height=10,
          aspect=1.5,
          palette="gist_ncar",
          scatter_kws={'edgecolor':'k',
                      's':80})

# %%
Z = shc.linkage(data, method='ward')

plt.figure(figsize=(15, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Distance')
dend = shc.dendrogram(Z)

# %%
from scipy.cluster.hierarchy import fcluster

k=13
temp = fcluster(Z, k, criterion='maxclust')

new_df['hierarchy'] = temp

df_tf = pd.DataFrame(data, columns=vectorizer.get_feature_names())
df_tf['hierarchy'] = temp

plt.figure(figsize=(10,7))
sns.lmplot(x="umap_0",
          y="umap_1",
          data=new_df,
          fit_reg=False,
          hue='hierarchy',
          legend=True,
          height=10,
          aspect=1.5,
          palette="gist_ncar",
          scatter_kws={'edgecolor':'k',
                      's':80})
# Out:
# C:\Users\tiffa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
def perc_func(x, cv_id, h):
    if x.name != cv_id:
        return (x - h[cv_id]).fillna(0)
    else:
        return x
    
def get_matching(cv_id, n_similar, single_tree, relative=False):
    neighbors = single_tree.get_nns_by_vector(data[cv_id], n=n_similar)
    
    table = df_tf.loc[neighbors].drop(['group', 'hierarchy'],1).T.sort_values(cv_id, ascending=False)
    indexes = set()
    
    for cv in neighbors:
        indexes.update(set(table.sort_values(cv, ascending=False).index[:7].tolist()))
        
    h = table.loc[indexes].sort_values(cv_id, ascending=False)
    
    info = h.apply(lambda x: perc_func(x, cv_id, h)) if relative else h
    
    info = (info * 100).round(1).style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
    
    return neighbors, info

def show_matching(cv_id, n_similar=1, metric='euclidean'):
    num_features = data.shape[1]
    single_tree = AnnoyIndex(num_features, metric=metric)
    
    i=0
    for vector in data:
        single_tree.add_item(i, vector)
        
        i += 1
    
    single_tree.build(1)
    
    neighbors, info = get_matching(cv_id, n_similar, single_tree, relative=False)
    return neighbors, info

# %%
res_id = 3
n_similar = 1

show_matching(res_id, n_similar=n_similar, metric='euclidean')[1]
# Out:
# C:\Users\tiffa\AppData\Local\Temp\ipykernel_13320\1721156656.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   table = df_tf.loc[neighbors].drop(['group', 'hierarchy'],1).T.sort_values(cv_id, ascending=False)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [421], in <cell line: 4>()
#       1 res_id = 3
#       2 n_similar = 1
# ----> 4 show_matching(res_id, n_similar=n_similar, metric='euclidean')[1]
#
# Input In [419], in show_matching(cv_id, n_similar, metric)
#      32     i += 1
#      34 single_tree.build(1)
# ---> 36 neighbors, info = get_matching(cv_id, n_similar, single_tree, relative=False)
#      37 return neighbors, info
#
# Input In [419], in get_matching(cv_id, n_similar, single_tree, relative)
#       7 def get_matching(cv_id, n_similar, single_tree, relative=False):
#       8     neighbors = single_tree.get_nns_by_vector(data[cv_id], n=n_similar)
# ---> 10     table = df_tf.loc[neighbors].drop(['group', 'hierarchy'],1).T.sort_values(cv_id, ascending=False)
#      11     indexes = set()
#      13     for cv in neighbors:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['group'] not found in axis"
